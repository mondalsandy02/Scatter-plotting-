# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data for GDP per capita (x) and life satisfaction (y)
x = np.array([5000, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000])
y = np.array([3, 5, 7, 6, 8, 7, 8.5, 7.5, 8, 6.5, 7])

# Fit a high-degree polynomial to the data (overfitting case)
coefficients = np.polyfit(x, y, deg=9)
polynomial = np.poly1d(coefficients)

# Generate smooth x values for plotting the polynomial
x_smooth = np.linspace(0, 100000, 1000)
y_smooth = polynomial(x_smooth)

# Plot the original data and the overfitted polynomial
plt.figure(figsize=(8, 5))
plt.scatter(x, y, color="blue", label="Data points")
plt.plot(x_smooth, y_smooth, color="red", label="Overfitted polynomial")
plt.xlabel("GDP per capita (USD)")
plt.ylabel("Life satisfaction")
plt.title("Overfitting the Training Data")
plt.legend()
plt.grid(True)
plt.show()
